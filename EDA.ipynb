# %% [markdown]
# ###  Data Description

# %% [markdown]
# Each feature or columns of different csv files are described below:
#
# The <code>olist_customers_dataset.csv</code> contain following features:
# * customer_id - Id of the consumer who made the purchase.
# * customer_unique_id - Unique Id of the consumer.
# * customer_zip_code_prefix - Zip Code of the location of the consumer.
# * customer_city - Name of the City from where order is made.
# * customer_state - tate Code from where order is made(Ex- sao paulo-SP).
#
# The <code>olist_geolocation_dataset.csv</code> contains following features:
# * geolocation_zip_code_prefix - first 5 digits of zip code
# * geolocation_lat - latitude
# * geolocation_lng - longitude
# * geolocation_city - city name
# * geolocation_state - state name
#
# The <code>olist_order_items_dataset.csv</code> contains following features:
# * order_id - A unique id of order made by the consumers.
# * order_item_id - A Unique id given to each item ordered in the order.
# * product_id -	A unique id given to each product available on the site.
# * seller_id	Unique - Id of the seller registered in olist.
# * shipping_limit_date -	The date before which shipping of the ordered product must be completed.
# * price - Actual price of the products ordered .
# * freight_value - Price rate at which a product is delivered from one point to another.
#
#
# The <code>olist_order_payments_dataset.csv</code> contains following features:
# * order_id - A unique id of order made by the consumers.
# * payment_sequential - sequences of the payments made in case of EMI.
# * payment_type - mode of payment used.(Ex-Credit Card)
# * payment_installments - number of installments in case of EMI purchase.
# * payment_value - Total amount paid for the purshase order.
#
#
# The <code>olist_order_reviews_dataset.csv</code> contains following features:
# * review_id -Id of the review given on the product ordered by the order id.
# * order_id - A unique id of order made by the consumers.
# * review_score - review score given by the customer for each order on the scale of 1–5.
# * review_comment_title - Title of the review
# * review_comment_message - Review comments posted by the consumer for each order.
# * review_creation_date - Timestamp of the review when it is created.
# * review_answer_timestamp - Timestamp of the review answered.
#
# The <code>olist_orders_dataset.csv</code> contains following features:
# * order_id - A unique id of order made by the consumers.
# * customer_id -	Id of the consumer who made the purchase.
# * order_status - status of the order made i.e delivered, shipped etc.
# * order_purchase_timestamp - Timestamp of the purchase.
# * order_approved_at - Timestamp of the order approval.
# * order_delivered_carrier_date - delivery date at which carrier made the delivery.
# * order_delivered_customer_date - date at which customer got the product.
# * order_estimated_delivery_date - estimated delivery date of the products.
#
# The <code>olist_products_dataset.csv</code> contains following features:
# * product_id - A unique identifier for the proposed project.
# * product_category_name - Name of the product category
# * product_name_lenght - * length of the string which specify the name given to the products ordered.
# * product_description_lenght - length of the description written for each product ordered on the site.
# * product_photos_qty - Number of photos of each product ordered available on the shopping portal.
# * product_weight_g - Weight of the products ordered in grams.
# * product_length_cm -	Length of the products ordered in centimeters.
# * product_height_cm -	Height of the products ordered in centimeters.
# * product_width_cm - width of the product ordered in centimeters.
#
# The <code>olist_sellers_dataset.csv</code> contains following features:
# * seller_id	Unique - Id of the seller registered in olist.
# * seller_zip_code_prefix - Zip Code of the location of the seller.
# * seller_city -	Name of the City of the seller.
# * seller_state - State Code (Ex- sao paulo-SP)
#
# The <code>product_category_name_translation.csv</code> contains following features:
# * product_category_name - category name in Portuguese
# * product_category_name_english - category name in English

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
customer_data = pd.read_csv("olist_customers_dataset.csv")
customer_data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
print(customer_data.shape)
print(customer_data.columns)
# Out:
# (99441, 5)
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
geo_data = pd.read_csv("olist_geolocation_dataset.csv")
geo_data.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
print(geo_data.shape)
print(geo_data.columns)
# Out:
# (1000163, 5)
# Index(['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng',
#        'geolocation_city', 'geolocation_state'],
#       dtype='object')

# %%
order_item_data = pd.read_csv("olist_order_items_dataset.csv")
order_item_data.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
print(order_item_data.shape)
print(order_item_data.columns)
# Out:
# (112650, 7)
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
order_pay_data = pd.read_csv("olist_order_payments_dataset.csv")
order_pay_data.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
print(order_pay_data.shape)
print(order_pay_data.columns)
# Out:
# (103886, 5)
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
order_review_data = pd.read_csv("olist_order_reviews_dataset.csv")
order_review_data.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
print(order_review_data.shape)
print(order_review_data.columns)
# Out:
# (100000, 7)
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
orders_data = pd.read_csv("olist_orders_dataset.csv")
orders_data.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
print(orders_data.shape)
print(orders_data.columns)
# Out:
# (99441, 8)
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
order_product_data = pd.read_csv("olist_products_dataset.csv")
order_product_data.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
print(order_product_data.shape)
print(order_product_data.columns)
# Out:
# (32951, 9)
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
seller_data = pd.read_csv("olist_sellers_dataset.csv")
seller_data.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
print(seller_data.shape)
print(seller_data.columns)
# Out:
# (3095, 4)
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')

# %%
product_cat_name_trans_data = pd.read_csv("product_category_name_translation.csv")
product_cat_name_trans_data.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
print(product_cat_name_trans_data.shape)
print(product_cat_name_trans_data.columns)
# Out:
# (71, 2)
# Index(['product_category_name', 'product_category_name_english'], dtype='object')

# %%
datasets = [customer_data, geo_data, order_item_data, order_pay_data, orders_data, order_product_data, order_review_data, seller_data, product_cat_name_trans_data]
titles = ["customers","geolocations","items", "payments", "orders", "products","reviews","sellers","category_translation"]

info_df_n = pd.DataFrame({},)

info_df_n['dataset']= titles

#creating column of name of columns in the dataset 
info_df_n['cols'] = [', '.join([col for col, null in df.isnull().sum().items() ]) for df in datasets]

#creating total number of columns in the dataset 
info_df_n['cols_no']= [df.shape[1] for df in datasets]

#counting total null values
info_df_n['null_no']= [df.isnull().sum().sum() for df in datasets]

#creating total number of columns in the dataset with null-values 
info_df_n['null_cols_no']= [len([col for col, null in df.isnull().sum().items() if null > 0]) for df in datasets]

#creating column of name of columns in the dataset with null-values 
info_df_n['null_cols'] = [', '.join([col for col, null in df.isnull().sum().items() if null > 0]) for df in datasets]


info_df_n.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow0_col2,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow1_col2,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow3_col2{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow0_col3,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow0_col4,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow1_col3,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow1_col4,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow2_col3,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow2_col4,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow3_col3,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow3_col4,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow7_col3,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow7_col4,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow8_col2,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow8_col3,#T_cf2e85e2_eab3_11eb_a761_b4b686bbbbbbrow8_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# ##### The maximum number of null-values are present in reviews dataset and the name of the columns with the null-values are review_comment_title and review_comment_message.

# %%
review_new = order_review_data.drop(['review_comment_title','review_creation_date','review_id','review_answer_timestamp'],axis=1)

# %%
df = pd.merge(orders_data, order_pay_data, on="order_id")
df = df.merge(customer_data, on="customer_id")
df = df.merge(order_item_data, on="order_id")
df = df.merge(order_product_data, on="product_id")
df = df.merge(product_cat_name_trans_data, on="product_category_name")
df = df.merge(review_new, on="order_id")
df = df.merge(seller_data, on="seller_id")
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-08-15 18:29:31  2017-08-15 20:05:16
# 4    delivered      2017-08-02 18:24:47  2017-08-02 18:43:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
print("Number of rows after merging:",len(df))
print("Number of columns after merging:",len(df.columns))
# Out:
# Number of rows after merging: 116581
# Number of columns after merging: 36

# %%
# Check missing values
df.isnull().sum()
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                   14
# order_delivered_carrier_date      1213
# order_delivered_customer_date     2515
# order_estimated_delivery_date        0
# payment_sequential                   0
# payment_type                         0
# payment_installments                 0
# payment_value                        0
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# product_category_name                0
# product_name_lenght                  0
# ...

# %% [markdown]
# ##### Handling Missing values in Timestamps -
#
# * The order of different types of timestamps are:
#
#         order_purchase_timestamp > order_approved_at > order_delivered_carrier_date > order_delivered_customer_date > order_estimated_delivery_date
#
# * Timestamps containg missing values are order_approved_at, order_delivered_carrier_date, order_delivered_customer_date
#
# * Null-values in order_approved_at can be replaced by order_purchase_timestamp and null-values in order_delivered_customer_date can be replaced by order_estimated_delivery_date
#
# * We can drop the column order_delivered_carrier_date.

# %%
#Handling missing values
index = (df[df['order_delivered_customer_date'].isnull() == True].index.values)

df["order_approved_at"].fillna(df["order_purchase_timestamp"], inplace=True)
df["order_delivered_customer_date"].fillna(df["order_estimated_delivery_date"], inplace=True)

# %%
#dropping order delivery carrier date
df.drop(labels='order_delivered_carrier_date',axis=1,inplace=True)

# %%
#checking the replaced values
df.order_estimated_delivery_date[index[0]]
# Out:
# '2017-05-16 00:00:00'

# %%
df.order_delivered_customer_date[index[0]]
# Out:
# '2017-05-16 00:00:00'

# %%
# Handling missing values of numerical features
df['product_weight_g'].fillna(df['product_weight_g'].median(),inplace=True)
df['product_length_cm'].fillna(df['product_length_cm'].median(),inplace=True)
df['product_height_cm'].fillna(df['product_height_cm'].median(),inplace=True)
df['product_width_cm'].fillna(df['product_width_cm'].median(),inplace=True)

# %%
#Handling missing values of text column
print("Percentage of null reviews :",(df.review_comment_message.isnull().sum()/len(df))*100 ,"%")
# filling null value of review comments with no_review
df['review_comment_message'].fillna('no_review',inplace=True)
# Out:
# Percentage of null reviews : 57.21601290090151 %

# %%
df.head(20)
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3   128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4   0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 5   bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 6   5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
# 7   1fa40f202d5d233b6491e976c557b822  50fd5707c28d0a64dc20d67f937dd9ba
# 8   41c045db2d1876be9f05cf4a787693b2  a286f46d6e54cc0179bbb0ee07b0df5e
# 9   4ec007fa66327a51919a32d840b49395  37495158e596d9ed20f3a53e8beab81b
# 10  27bef9e280946001761b32ae6463dbe0  226f45581c1b5fe6ab7ac0d9e060a2c4
# 11  60d13096e69ace88a0c5b8c3805010ca  54bd7edf8250e9e67794e9df507e3720
# ...

# %% [markdown]
# #### Duplicate Data

# %%
dup_rows = df[df.duplicated(['order_id','customer_id','order_purchase_timestamp','order_delivered_customer_date','customer_unique_id','review_comment_message'])]
dup_rows.head()
# Out:
#                             order_id                       customer_id  \
# 1   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 22  e71fb32bec49dd4112bcbcc19126d388  f6c383cc79b182ce1550bc57504941c3
# 30  f37bdf37547266e7d6760e52bc87dfe3  8860eda9f0c775c17cf854564eab3418
# 43  5c63162ff15f6e39ca02c3dbc82ecf65  d27812f504d4415e126b6fba33f631d0
#
#    order_status order_purchase_timestamp    order_approved_at  \
# 1     delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2     delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 22    delivered      2017-08-02 22:12:03  2017-08-02 22:25:18
# 30    delivered      2017-07-25 16:49:56  2017-07-25 17:03:22
# 43    delivered      2017-10-13 22:30:31  2017-10-13 22:45:31
#
#    order_delivered_customer_date order_estimated_delivery_date  \
# 1            2017-10-10 21:25:13           2017-10-18 00:00:00
# ...

# %%
#Deduplication of entries
df= df.drop_duplicates(subset={'order_id','customer_id','order_purchase_timestamp','order_delivered_customer_date'}, keep='first', inplace=False)
df=df.reindex()
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 5  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 6  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-08-15 18:29:31  2017-08-15 20:05:16
# 4    delivered      2017-08-02 18:24:47  2017-08-02 18:43:15
# 5    delivered      2017-10-23 23:26:46  2017-10-25 02:14:11
# 6    delivered      2017-08-24 11:31:28  2017-08-24 11:45:25
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-10-10 21:25:13           2017-10-18 00:00:00
# ...

# %%
print("Number of rows after dedublication:",len(df))
print("Number of columns after deduplication:",len(df.columns))
# Out:
# Number of rows after dedublication: 97255
# Number of columns after deduplication: 35

# %% [markdown]
# ## EDA

# %%
# All time stamps are in object dtype as observed. Converting it into dataetime
df[['order_purchase_timestamp','order_approved_at','order_delivered_customer_date','order_estimated_delivery_date']]=df[['order_purchase_timestamp',
       'order_approved_at','order_delivered_customer_date','order_estimated_delivery_date']].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97255 entries, 0 to 116579
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       97255 non-null  object
#  1   customer_id                    97255 non-null  object
#  2   order_status                   97255 non-null  object
#  3   order_purchase_timestamp       97255 non-null  datetime64[ns]
#  4   order_approved_at              97255 non-null  datetime64[ns]
#  5   order_delivered_customer_date  97255 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  97255 non-null  datetime64[ns]
#  7   payment_sequential             97255 non-null  int64
#  8   payment_type                   97255 non-null  object
#  9   payment_installments           97255 non-null  int64
#  10  payment_value                  97255 non-null  float64
#  11  customer_unique_id             97255 non-null  object
# ...

# %% [markdown]
# The final merged dataset has no null values.

# %%
df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value  \
# count        97255.000000          97255.000000   97255.000000
# mean             1.022590              2.922143     158.146126
# std              0.247582              2.714211     217.969505
# min              1.000000              0.000000       0.010000
# 25%              1.000000              1.000000      60.100000
# 50%              1.000000              2.000000     103.260000
# 75%              1.000000              4.000000     175.640000
# max             27.000000             24.000000   13664.080000
#
#        customer_zip_code_prefix  order_item_id         price  freight_value  \
# count              97255.000000   97255.000000  97255.000000   97255.000000
# mean               35146.411999       1.017511    125.931660      20.221336
# std                29787.788224       0.153488    190.873699      15.937803
# min                 1003.000000       1.000000      0.850000       0.000000
# ...

# %%
# checking the target variables i.e review score 
df.review_score.value_counts()
# Out:
# 5    56274
# 4    18785
# 1    11011
# 3     8084
# 2     3101
# Name: review_score, dtype: int64

# %%
def partition(x):
    if x < 3:
        return 0
    return 1
df['review_score']=df['review_score'].map(lambda cw : partition(cw) ) 
    
# checking the review score now
df.review_score.value_counts()
# Out:
# 1    83143
# 0    14112
# Name: review_score, dtype: int64

# %%
#counting the review score with 1 and 0
y_value_counts = df.review_score.value_counts()

#calculating the percentage of each review type
print("Total Positive Reviews :", y_value_counts[1], ", (", (y_value_counts[1]/(y_value_counts[1]+y_value_counts[0]))*100,"%)")
print("Total Negative Reviews :", y_value_counts[0], ", (", (y_value_counts[0]/(y_value_counts[1]+y_value_counts[0]))*100,"%)")
print('\n')

#plotting bar-plot and pie chart
# %matplotlib inline
sns.set_style("whitegrid")
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.ylabel('Total Reviews')
plt.xlabel('Label')
plt.title('Negative Vs Positive Reviews',color='dimgrey')
plt.xticks([10,10.20],['0','1'])
#creating bar plots
plt.bar(10.20,83143,color = 'green', width = 0.15,alpha=0.9,label='positive',edgecolor='black')
plt.bar(10,14112, color = '#2e4884', width = 0.15,alpha=0.7,label='negative',edgecolor='black')
plt.legend()

plt.subplot(1,2,2)
labels = ['Positive','Negative']
sizes = [83143,14112]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')
color={'#2e4884', 'green'}
plt.pie(sizes,explode=explode ,colors=color,labels=labels, autopct='%1.1f%%',shadow=False, startangle=0,radius=1.5,labeldistance=1.1,textprops={'fontsize': 14},frame=True, )
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Pie Chart for review score',color='dimgrey')
plt.show()
# Out:
# Total Positive Reviews : 83143 , ( 85.48969204668141 %)
# Total Negative Reviews : 14112 , ( 14.510307953318597 %)

# %% [markdown]
# We can observe from the above plots 85.5% of the total reviews are positive i.e. 1 and only 14.5% reviews are negative i.e. which means that the given data set is imbalanced dataset.

# %% [markdown]
# ### Heatmap

# %%
#Correlation matrix 
corr_matrix = df.corr()

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.3)
cmap = sns.light_palette("#2f3b39",as_cmap=True)
sns.heatmap(corr_matrix, cmap=cmap,annot=True)
plt.title("  Correlation Matrix of the features",fontsize=19)
plt.savefig('plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# There is a strong positive correlation between: (payment_value and price), (product_weight_g and freight_value also with product_width_cm), (product_length_cm and product_width_cm), (product_height_cm and product_weight_g)

# %%
#finding corr- values of the features with review_score
corr_matrix["review_score"].sort_values(ascending=False)
# Out:
# review_score                  1.000000
# seller_zip_code_prefix        0.020689
# product_photos_qty            0.018041
# product_description_lenght    0.009463
# product_name_lenght          -0.000562
# payment_sequential           -0.005685
# product_width_cm             -0.010906
# customer_zip_code_prefix     -0.011552
# product_length_cm            -0.015099
# price                        -0.022045
# product_height_cm            -0.022712
# product_weight_g             -0.028201
# freight_value                -0.036729
# payment_installments         -0.037245
# payment_value                -0.054138
# order_item_id                -0.071496
# Name: review_score, dtype: float64

# %%
#checking unique ids
print("Total number of unique seller_id:",len((df.seller_id).unique()))
print("Total number of unique product_id:",len((df.product_id).unique()))
print("Total number of unique customer_id:",len((df.customer_unique_id).unique()))
# Out:
# Total number of unique seller_id: 3018
# Total number of unique product_id: 31109
# Total number of unique customer_id: 94087

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
sns.set_style("whitegrid")
plt.ylabel('No of Unique Id')
plt.xlabel('Different Unique Id')
plt.title('Total Unique Ids',color='dimgrey')
plt.xticks([10,10.25,10.50],['seller_id','product_id','customer_id'])
#creating bar plots
plt.bar(10,3022, color = '#E9F6FA', width = 0.25,alpha=0.7,label='seller_id',edgecolor='black')
plt.bar(10.25,31053, color = '#A5C1DC', width = 0.25,alpha=0.8,label='product_id',edgecolor='black')
plt.bar(10.50,94087, color = '#7982B9', width = 0.25,alpha=0.9,label='customer_id',edgecolor='black')
plt.legend()
plt.show()

# %% [markdown]
# After comparing different ids it can be observed that the highest number of unique id is of customers and least is from sellers

# %% [markdown]
# ## Univariate Analysis: Payment Type

# %%
df.groupby('payment_type').size()
# Out:
# payment_type
# boleto         19345
# credit_card    73816
# debit_card      1490
# voucher         2604
# dtype: int64

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.ylabel('Total')
plt.xlabel('payment_type')
plt.title('Total Payment Type',color='dimgrey')
plt.xticks([10,10.25,10.50,10.75],['debit_card','voucher','boleto','credit_card'])
#creating bar plots
plt.bar(10.75,73816, color = '#9B3192', width = 0.25,alpha=0.8,label='credit_card',edgecolor='black')
plt.bar(10.50,19345, color = '#EA5F89', width = 0.25,label='boleto',edgecolor='black')
plt.bar(10.25,2604, color = '#F7B7A3', width = 0.25,alpha=0.5,label='voucher',edgecolor='black')
plt.bar(10,1490, color = '#FFF1C9', width = 0.25,alpha=0.8,label='debit_card',edgecolor='black')

plt.legend()
plt.show()

# %% [markdown]
# Most of the customers have paid for their orders using credit card and the second most used payment method is boleto.

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1,2,2)
s= [ 73816,19345, 2604,1490]
new = ['credit_card','boleto','voucher','debit_card']

explode = (0, 0, 0,0)  
colours = {'credit_card': '#9B3192',
           'boleto': '#EA5F89',
           'voucher': '#F7B7A3',
           'debit_card': '#FFF1C9'}

color ={'#2e4884','grey','#d8d8d8','w'}



plt.pie(s, explode=explode, labels=new,colors=[colours[key] for key in new] , autopct='%1.1f%%',shadow=False, startangle=70,radius=1.5,frame=True,textprops={'fontsize': 10})
plt.axis('equal') 
plt.title('Pie Chart for Payment method type',color='dimgrey')
plt.show()

# %% [markdown]
# The percentage of each mode of payment is shown in pie chart which shows that amongst all payments made by the user the credit card is used by 75.9% of the users, baleto is used by 19.9% of the user and 3.2% of the user used voucher and debit card.

# %% [markdown]
# ### Univariate Analysis: Payment Installments

# %%
df.groupby('payment_installments').size()
# Out:
# payment_installments
# 0         2
# 1     47498
# 2     11955
# 3     10148
# 4      6896
# 5      5090
# 6      3801
# 7      1570
# 8      4170
# 9       625
# 10     5166
# 11       22
# 12      130
# 13       16
# 14       14
# 15       73
# 16        5
# 17        7
# 18       27
# 20       17
# 21        3
# 22        1
# 23        1
# 24       18
# dtype: int64

# %%
plt.figure(figsize = (15,7))
ax=sns.countplot(x=df['payment_installments'], data=df, palette='viridis')
plt.title('Payments Into Installments Count', color='dimgrey', fontsize=20)
plt.xlabel('No of installments', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation= 0)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.10, p.get_height()+0.50))
plt.show()

# %% [markdown]
# Most of our customers tend to pay the value of there orders as 1 installment.

# %% [markdown]
# ### Univariate Analysis: Customer count based on State wise

# %%
plt.figure(figsize=(15,7))
sns.set_style("whitegrid")
ax = df.customer_state.value_counts().sort_values(ascending=False)[0:15].plot(kind='bar', color = 'purple', alpha=0.8)
ax.set_title("Top 15 consumer states of Brazil")
ax.set_xlabel("States")
plt.xticks(rotation=0)
ax.set_ylabel("No of consumers")
plt.show()

# %% [markdown]
# Most of the customers are located in states Sao Paulo(SP), Rio de Janeiro(RJ) and Minas Gerais(MG).

# %%
def stack_plot(data, xtick, col2, col3='total'):
    ind = np.arange(data.shape[0])
    
    plt.figure(figsize=(20,5))
    p1 = plt.bar(ind, data[col3].values,color = 'grey',alpha=0.5)
    p2 = plt.bar(ind, data[col2].values,color= 'purple',alpha=0.8)

    plt.xlabel('State Name')
    plt.ylabel('Reviews')
    plt.title('% of review_score  ')
    plt.xticks(ind-0.1, list(data[xtick].values), rotation=0)
    plt.legend((p1[0], p2[0]), ('total_reviews', 'positive_review'))
    plt.show()

# %%
temp_1 = pd.DataFrame(df.groupby('customer_state')['review_score'].agg(lambda x: x.eq(1).sum())).reset_index()

temp_1['total'] = list(pd.DataFrame(df.groupby('customer_state')['review_score'].agg([('total','count'),('Avg','mean')]))['total'])
temp_1['Avg']   = list(pd.DataFrame(df.groupby('customer_state')['review_score'].agg([('total','count'),('Avg','mean')]))['Avg'])
temp_1= temp_1.rename(columns={'review_score':'positive_review'})
temp_1= temp_1.sort_values(by=['total'], ascending=False)

# %%
temp_1
# Out:
#    customer_state  positive_review  total       Avg
# 25             SP            35791  40800  0.877230
# 18             RJ             9968  12569  0.793062
# 10             MG             9875  11375  0.868132
# 22             RS             4650   5351  0.868996
# 17             PR             4325   4928  0.877638
# 23             SC             3039   3554  0.855093
# 4              BA             2677   3314  0.807785
# 6              DF             1784   2094  0.851958
# 7              ES             1699   2008  0.846116
# 8              GO             1670   1959  0.852476
# 15             PE             1355   1630  0.831288
# 5              CE             1060   1312  0.807927
# 13             PA              762    951  0.801262
# 12             MT              766    891  0.859708
# 9              MA              569    730  0.779452
# 11             MS              603    700  0.861429
# 14             PB              435    523  0.831740
# ...

# %%
stack_plot(temp_1,'customer_state',col2='positive_review', col3='total')

# %% [markdown]
# From the avove stack plot of reviews per state we can conclude that most of consumers from each state has given positive reviews.In SP state from the total reviews of 40800 , 35791 reviews are positive reviews and for RJ state 9968 reviews are positive from the total reviews 12569.

# %% [markdown]
# ### Univariate Analysis: Customer count based on City wise

# %%
plt.figure(figsize=(15,7))
sns.set_style("whitegrid")
ax = df.customer_city.value_counts().sort_values(ascending=False)[0:15].plot(kind='bar', color = '#7982B9', alpha=0.8)
ax.set_title("Top 15 consumer cities of Brazil")
ax.set_xlabel("City Name")
plt.xticks(rotation=90)
ax.set_ylabel("No of consumers")
plt.show()

# %% [markdown]
# Most of customers are located in city Sao Paulo followed by Rio De Janerio and Belo Horizonto

# %% [markdown]
# ### Univariate Analysis: Seller count based on State wise

# %%
plt.figure(figsize=(15,7))
sns.set_style("whitegrid")
ax = df.seller_state.value_counts().sort_values(ascending=False)[0:15].plot(kind='bar', color = 'brown', alpha=0.8)
ax.set_title("Top 15 seller states of Brazil")
ax.set_xlabel("States")
plt.xticks(rotation=0)
ax.set_ylabel("No of sellers")
plt.show()

# %% [markdown]
# Most of the sellers are located in Sao Paulo(SP) and the rest is distributed between Minas Gerais(MG), Parana(PR), Rio de Janeiro(RJ).

# %% [markdown]
# ### Univariate Analysis: Seller count based on City wise

# %%
plt.figure(figsize=(15,7))
sns.set_style("whitegrid")
ax = df.seller_city.value_counts().sort_values(ascending=False)[0:15].plot(kind='bar', color = 'green', alpha=0.8)
ax.set_title("Top 15 seller cities of Brazil")
ax.set_xlabel("City Name")
plt.xticks(rotation=90)
ax.set_ylabel("No of sellers")
plt.show()

# %% [markdown]
# Salo Paulo has the highest no. of sellers amongst all cities in Brazil followed by Ibitinga and Santo Andre.

# %% [markdown]
# ### Univariate Analysis: Product Category Name English

# %%
plt.figure(figsize=(15,7))
sns.set_style("whitegrid")
ax = df.product_category_name_english.value_counts().sort_values(ascending=False)[0:15].plot(kind='bar', color = 'orange', alpha=0.8)
ax.set_title("Top selling product categories")
ax.set_xlabel("States")
plt.xticks(rotation=90)
ax.set_ylabel("No of Orders")
plt.show()

# %% [markdown]
# bed-bath-tables is the most desirable product category.

# %%
temp_2 = pd.DataFrame(df.groupby('product_category_name_english')['review_score'].agg(lambda x: x.eq(1).sum())).reset_index()

temp_2['total'] = list(pd.DataFrame(df.groupby('product_category_name_english')['review_score'].agg([('total','count'),('Avg','mean')]))['total'])
temp_2['Avg']   = list(pd.DataFrame(df.groupby('product_category_name_english')['review_score'].agg([('total','count'),('Avg','mean')]))['Avg'])
temp_2 = temp_2.sort_values(by=['total'], ascending=True)
temp_2
# Out:
#    product_category_name_english  review_score  total       Avg
# 61         security_and_services             1      2  0.500000
# 29     fashion_childrens_clothes             5      6  0.833333
# 11             cds_dvds_musicals            12     12  1.000000
# 52                    la_cuisine            10     13  0.769231
# 3          arts_and_craftmanship            19     22  0.863636
# ..                           ...           ...    ...       ...
# 39               furniture_decor          5290   6351  0.832940
# 15         computers_accessories          5580   6663  0.837461
# 65                sports_leisure          6663   7679  0.867691
# 43                 health_beauty          7655   8795  0.870381
# 7                 bed_bath_table          7744   9341  0.829033
#
# [71 rows x 4 columns]

# %%
plt.figure(figsize=(22,18))
p1 = plt.barh(temp_2.product_category_name_english,temp_2.total,color='grey',alpha=0.4)
p2 = plt.barh(temp_2.product_category_name_english,temp_2.review_score,color='orange',alpha=0.7)
plt.title('Top Selling Product Categories',fontsize=22,color='dimgrey')
plt.ylabel('product_category_name_english',fontsize=14)
plt.xlabel('Total',fontsize=14)
plt.legend((p1[0], p2[0]), ('total_reviews', 'positive_review'))
plt.savefig('plot1.png', dpi=480, bbox_inches='tight')
plt.show()

# %% [markdown]
# Most of the reviews for the product category bed_bath_table are positive and it is same for the other product categories

# %% [markdown]
# ### Univariate Analysis: Order Status

# %%
plt.figure(figsize = (15,7))
ax=sns.countplot(x='order_status',data=df)
plt.title('Order Status',color='dimgrey', fontsize=20)
plt.xlabel("Order Status",fontsize=14)
plt.ylabel("No of Orderst",fontsize=14)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.30, p.get_height()+0.50))
plt.show()

# %% [markdown]
#  Most of the orders have been delivered

# %%
plt.figure(figsize = (15,7))
ax=sns.countplot(x='order_status', hue='review_score', data=df)
plt.title('Order Status',color='dimgrey', fontsize=20)
plt.xlabel("Order Status",fontsize=14)
plt.ylabel("No of Orderst",fontsize=14)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.10, p.get_height()+0.50))
plt.show()

# %% [markdown]
#  The order_status delivered most of the order are with positive reviews

# %% [markdown]
# ### Univariate Analysis on different Timestamps

# %%
#calulating number of days for the data is taken
print(df.order_approved_at.max() - df.order_approved_at.min(), ' from ', 
      df.order_approved_at.min(), ' to ', df.order_approved_at.max())
# Out:
# 699 days 07:56:34  from  2016-10-04 09:43:32  to  2018-09-03 17:40:06

# %%
# Extracting attributes for purchase date - Year and Month
df['order_purchase_year'] = df['order_purchase_timestamp'].apply(lambda x: x.year) #gives year Example :2016-10-04 09:43:32 ---->2016
df['order_purchase_month'] = df['order_purchase_timestamp'].apply(lambda x: x.month) #gives month Example :2016-10-04 09:43:32 ---->10
df['order_purchase_month_name'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%b'))#gives month in short form Example :2016-10-04 09:43:32 ---->10--> Oct
df['order_purchase_year_month'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m'))#gives month&year Example :2016-10-04 09:43:32 ---->201610
df['order_purchase_date'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m%d'))#gives month,yr and date  Example :2016-10-04 09:43:32 ---->20161004
df['order_purchase_month_yr'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime("%b-%y"))

# Extracting attributes for purchase date - Day and Day of Week
df['order_purchase_day'] = df['order_purchase_timestamp'].apply(lambda x: x.day)
df['order_purchase_dayofweek'] = df['order_purchase_timestamp'].apply(lambda x: x.dayofweek)
df['order_purchase_dayofweek_name'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%a'))

# Extracting attributes for purchase date - Hour and Time of the Day
df['order_purchase_hour'] = df['order_purchase_timestamp'].apply(lambda x: x.hour)
hours_bins = [0,4,8,12,16,20,24]
hours_labels = ['Late Night', 'Early Morning','Morning','Noon','Eve','Night']
df['order_purchase_time_day'] = pd.cut(df['order_purchase_hour'], hours_bins, labels=hours_labels)

# New DataFrame after transformations
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 5  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 6  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2017-08-15 18:29:31 2017-08-15 20:05:16
# 4    delivered      2017-08-02 18:24:47 2017-08-02 18:43:15
# 5    delivered      2017-10-23 23:26:46 2017-10-25 02:14:11
# 6    delivered      2017-08-24 11:31:28 2017-08-24 11:45:25
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-10-10 21:25:13                    2017-10-18
# ...

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=df['order_purchase_year_month'].value_counts().sort_index(), 
             color='black', linewidth=2)
plt.title('Evolution of Total Orders in Brazilian E-Commerce', size=14, color='dimgrey')
plt.xticks(rotation=90)
plt.xlabel('YearMonth')
plt.ylabel('No. of orders')
plt.show()

# %% [markdown]
# we can observe that the number of purchase is increasing from 201609 to 201711(highest) and then decreases for a short sapn which means the either orders from the older customers are increasing or the number of consumers are increasing.

# %%
df_month = pd.DataFrame()
df_month['date'],df_month['review_score']= list(df.order_approved_at),list(df.review_score)
df_month=df_month.dropna()
df_month = df_month.sort_values(by=['date'])

# %%
df_month['monthcount'] = list(df_month.date.apply(lambda x: x.strftime("%b-%y")))
#plotting number of orders per month-year
plt.figure(figsize=(22,7))
g = sns.countplot(x=df_month.monthcount,data=df_month,color='orange',edgecolor='grey')
g.set_xticklabels(g.get_xticklabels(), rotation=0)
g.set_xlabel('Month-Year')
g.set_ylabel('Orders Count')
plt.title('Number of orders per month-year', size=14, color='dimgrey');

# %% [markdown]
# It can be observed that the highest number of orders are received in the month of November in the year 2017  which is more the 7000 approx. and the least number of orders are received in the month of Dec in the year 2016.

# %%
#plotting number of positive and negative reviews per month-year
plt.figure(figsize=(22,7))
g = sns.countplot(x=df_month.monthcount,hue='review_score',data=df_month,palette=['grey','orange'],edgecolor='grey')
g.set_xticklabels(g.get_xticklabels(), rotation=0)
g.set_xlabel('Month-Year')
g.set_ylabel('Orders Count')
plt.title('Number of positive and negative reviews per month-year', size=14, color='dimgrey');

# %% [markdown]
# It can observed that most of the orders have given positive reviews. From the above plot we can see the highest positive reviews were given on May-18

# %%
plt.figure(figsize = (15,7))
ax=sns.countplot(x='order_purchase_time_day', data=df, palette='rainbow')
plt.title('No. of orders across Part of Day',color='dimgrey', fontsize=20)
plt.xlabel("Part of Day",fontsize=14)
plt.ylabel("No of Orders",fontsize=14)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.30, p.get_height()+0.50))
plt.show()

# %% [markdown]
# Maximum no of orders were placed at Noon time

# %% [markdown]
# ### Text Analysis

# %%
order_review_data.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_review_data.shape
# Out:
# (100000, 7)

# %%
order_review_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_comment_title     11715 non-null   object
#  4   review_comment_message   41753 non-null   object
#  5   review_creation_date     100000 non-null  object
#  6   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
review_data_title = order_review_data['review_comment_title']
review_data = order_review_data.drop(['review_comment_title'],axis=1)

# Dropping NaN values
review_data  = review_data.dropna()
review_data_title = review_data_title.dropna()

# %%
# Resetting the reviews index and visualizing the data
review_data = review_data.reset_index(drop=True)
review_data.head()
# Out:
#                           review_id                          order_id  \
# 0  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
#
#    review_score                             review_comment_message  \
# 0             5              Recebi bem antes do prazo estipulado.
# 1             5  Parabéns lojas lannister adorei comprar pela I...
# 2             4  aparelho eficiente. no site a marca do aparelh...
# 3             4    Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 4             5  Vendedor confiável, produto ok e entrega antes...
#
#   review_creation_date review_answer_timestamp
# 0  2017-04-21 00:00:00     2017-04-21 22:02:06
# ...

# %%
review_data.shape
# Out:
# (41753, 6)

# %%
# Resetting the reviews titles index and visualizing the data
review_data_title = review_data_title.reset_index(drop=True)
review_data_title.head()
# Out:
# 0                  recomendo
# 1            Super recomendo
# 2    Não chegou meu produto
# 3                      Ótimo
# 4                 Muito bom.
# Name: review_comment_title, dtype: object

# %%
review_data_title.shape
# Out:
# (11715,)

# %%
import re, nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
comments = []
stop_words = set(stopwords.words('portuguese'))


for words in review_data['review_comment_message']:
    only_letters = re.sub("[^a-zA-Z]", " ",words)
    tokens = nltk.word_tokenize(only_letters) #tokenize the sentences
    lower_case = [l.lower() for l in tokens] #convert all letters to lower case
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case)) #Remove stopwords from the comments
    comments.append(' '.join(filtered_result))

# %%
#Using wordcloud to visualize the comments
unique_string=(" ").join(comments)
wordcloud = WordCloud(width = 2000, height = 1000,background_color='white').generate(unique_string)
plt.figure(figsize=(20,12))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('word_cloud_pt.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# The Wordcloud above shows the most frequent words in Portuguese.

# %%
from collections import Counter

# %%
words = (" ".join(review_data['review_comment_message'])).lower().split()
counts = Counter(words)

# %%
print("Most frequent words:")
sorted(counts.items(), key=lambda x: x[1], reverse=True)[:15]
# Out:
# Most frequent words:
# [('o', 19492),
#  ('e', 16147),
#  ('produto', 15799),
#  ('a', 12623),
#  ('de', 11752),
#  ('do', 11375),
#  ('não', 11137),
#  ('que', 8706),
#  ('muito', 7689),
#  ('com', 5856),
#  ('antes', 5560),
#  ('entrega', 5469),
#  ('no', 5321),
#  ('chegou', 5207),
#  ('recebi', 5146)]

# %%
print("Least frequent words:")
sorted(counts.items(), key=lambda x: x[1], reverse=False)[:15]
# Out:
# Least frequent words:
# [('3desinfector', 1),
#  ('nome...atualizar', 1),
#  (',travando...pelo', 1),
#  ('decpcionou', 1),
#  ('amim', 1),
#  ('dispensada', 1),
#  ('atrasaram,', 1),
#  ('apaixonada,', 1),
#  ('tomara', 1),
#  ('pelinho.', 1),
#  ('midea', 1),
#  ('split', 1),
#  ('estilo.', 1),
#  ('parceria:', 1),
#  ('rápidíssima,', 1)]

# %%
# Getting the number of words by splitting them by a space
plt.figure(figsize=(15,7))
words_per_review = review_data.review_comment_message.apply(lambda x: len(x.split(" ")))
words_per_review.hist(bins = 100)
plt.xlabel('Review Length (words)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Conclusions:
#
# 1. Most of our customers are located in Sao Paulo(SP), we can advise the stores to invest in advertising in different communities and more cities.
#
# 2. Most of our sellers are located in Sao Paulo(SP) too, to get the maximum profit sellers can invest in more store branches.
#
# 3. We can advise the new sellers with the top selling categories of products (bed bath tables, health-beauty, sports leisure, furniture decor, housewares, computer-accessories).
#
# 4. Most of our customers use their credit cards to pay with a minimum amount of installments, in this case, sellers can invest with banks and provide some offers and discounts to encourage customers more and more.
#
# 5. There is great growth in profits between 2017 and 2018, the orders reach their peak at 11/2017.
#
# 6. Most of the orders are placed during the noon.This will help to produce more effective advertising plans.
